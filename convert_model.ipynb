# %%
import torch
from src.constructor import BACKBONES

# %%
model = BACKBONES.get('efficientnet_b0')(pretrained=False, in_chans=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workdir/vpatrushev/small2/torchOK2/torchok/convert_model.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B34.247.183.220/workdir/vpatrushev/small2/torchOK2/torchok/convert_model.ipynb#ch0000001vscode-remote?line=0'>1</a> model = BACKBONES.get('efficientnet_b0')(pretrained=False, in_chans=3)
#
# File /workdir/vpatrushev/small2/torchOK2/torchok/src/models/backbones/efficientnet.py:153, in efficientnet_b0(pretrained, **kwargs)
#     150 @BACKBONES.register_class
#     151 def efficientnet_b0(pretrained: bool = False, **kwargs):
#     152     """EfficientNet-B0 """
# --> 153     model = create_effnet('efficientnet_b0', pretrained=pretrained, **kwargs)
#     154     return model
#
# ...

# %%
my_state_dict = torch.load('/workdir/vpatrushev/small2/torchOK2/torchok/mobilenetv3_large_torchok.pth')
model.load_state_dict(my_state_dict)
# Out:
# <All keys matched successfully>

# %%
model
# Out:
# MobileNetV3_Large(
#   (convbnact_stem): ConvBnAct(
#     (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): Hardswish()
#   )
#   (bneck): Sequential(
#     (0): InvertedResidualBlock(
#       (inverted_residual): Sequential(
#         (0): ConvBnAct(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBnAct(
#           (conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (inverted_residual): Sequential(
#         (0): ConvBnAct(
# ...

# %%
import torchvision

# %%
from torchvision.models import mobilenet_v3_large

# %%
mobilenet_v3_large()
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
# ...

# %%
print(model)
# Out:
# MobileNetV3_Large(
#   (convbnact_stem): ConvBnAct(
#     (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): Hardswish()
#   )
#   (bneck): Sequential(
#     (0): InvertedResidualBlock(
#       (inverted_residual): Sequential(
#         (0): ConvBnAct(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBnAct(
#           (conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): InvertedResidualBlock(
#       (inverted_residual): Sequential(
#         (0): ConvBnAct(
# ...

# %%
len(my_keys)
# Out:
# 308

# %%
my_keys
# Out:
# ['convbnact_stem.conv.weight',
#  'convbnact_stem.bn.weight',
#  'convbnact_stem.bn.bias',
#  'convbnact_stem.bn.running_mean',
#  'convbnact_stem.bn.running_var',
#  'convbnact_stem.bn.num_batches_tracked',
#  'bneck.0.inverted_residual.0.conv.weight',
#  'bneck.0.inverted_residual.0.bn.weight',
#  'bneck.0.inverted_residual.0.bn.bias',
#  'bneck.0.inverted_residual.0.bn.running_mean',
#  'bneck.0.inverted_residual.0.bn.running_var',
#  'bneck.0.inverted_residual.0.bn.num_batches_tracked',
#  'bneck.0.inverted_residual.1.conv.weight',
#  'bneck.0.inverted_residual.1.bn.weight',
#  'bneck.0.inverted_residual.1.bn.bias',
#  'bneck.0.inverted_residual.1.bn.running_mean',
#  'bneck.0.inverted_residual.1.bn.running_var',
#  'bneck.0.inverted_residual.1.bn.num_batches_tracked',
#  'bneck.1.inverted_residual.0.conv.weight',
#  'bneck.1.inverted_residual.0.bn.weight',
#  'bneck.1.inverted_residual.0.bn.bias',
#  'bneck.1.inverted_residual.0.bn.running_mean',
# ...

# %%
my_keys = []
for key, value in model.state_dict().items():
    my_keys.append(key)

# %%
mapdict = dict()
for external_key, my_key in zip(keys_state_dict[:-4], my_keys):
    mapdict[external_key] = my_key

# %%
my_tensor_state_dict = {}
for key in mapdict.keys():
    my_tensor_state_dict[mapdict[key]] = state_dict[key]

# %%
my_tensor_state_dict
# Out:
# {'convbnact_stem.conv.weight': tensor([[[[-5.2519e-03, -3.2783e-02,  1.0595e-01],
#            [-1.2849e-01,  2.1346e-01,  6.1627e-01],
#            [-9.4294e-02, -5.8107e-02,  2.8952e-01]],
#
#           [[ 1.2953e-01,  3.6688e-02,  1.8834e-01],
#            [-4.7164e-02,  1.3922e-01,  5.0325e-01],
#            [ 9.2799e-02,  8.7551e-02,  5.2051e-01]],
#
#           [[-1.7299e-02, -3.8238e-02, -6.1129e-02],
#            [-1.7281e-01,  8.6122e-02,  2.0740e-01],
#            [-9.2084e-02, -6.3704e-02,  9.8702e-02]]],
#
#
#          [[[-2.3221e-01,  4.9465e-02,  5.1348e-02],
#            [-4.5540e-02,  1.2232e+00, -1.0734e+00],
#            [ 3.9858e-02,  1.7052e+00, -1.7577e+00]],
#
#           [[-4.5753e-01,  2.1417e-01, -6.9173e-02],
#            [-4.9311e-02,  2.2667e+00, -2.0212e+00],
#            [ 1.8742e-01,  2.7476e+00, -2.8510e+00]],
#
#           [[-9.0108e-02,  5.0516e-02,  4.2271e-02],
#            [-1.2911e-02,  7.1184e-01, -6.6935e-01],
# ...

# %%
state_dict = torch.load('/workdir/vpatrushev/small2/mobilenet_v3_large-5c1a4163.pth')

# %%
state_dict['features.15.block.2.avgpool']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workdir/vpatrushev/small2/torchOK2/torchok/convert_model.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B34.247.183.220/workdir/vpatrushev/small2/torchOK2/torchok/convert_model.ipynb#ch0000008vscode-remote?line=0'>1</a> state_dict['features.15.block.2.avgpool']
#
# KeyError: 'features.15.block.2.avgpool'

# %%
state_dict
# Out:
# OrderedDict([('features.0.0.weight',
#               tensor([[[[-5.2519e-03, -3.2783e-02,  1.0595e-01],
#                         [-1.2849e-01,  2.1346e-01,  6.1627e-01],
#                         [-9.4294e-02, -5.8107e-02,  2.8952e-01]],
#
#                        [[ 1.2953e-01,  3.6688e-02,  1.8834e-01],
#                         [-4.7164e-02,  1.3922e-01,  5.0325e-01],
#                         [ 9.2799e-02,  8.7551e-02,  5.2051e-01]],
#
#                        [[-1.7299e-02, -3.8238e-02, -6.1129e-02],
#                         [-1.7281e-01,  8.6122e-02,  2.0740e-01],
#                         [-9.2084e-02, -6.3704e-02,  9.8702e-02]]],
#
#
#                       [[[-2.3221e-01,  4.9465e-02,  5.1348e-02],
#                         [-4.5540e-02,  1.2232e+00, -1.0734e+00],
#                         [ 3.9858e-02,  1.7052e+00, -1.7577e+00]],
#
#                        [[-4.5753e-01,  2.1417e-01, -6.9173e-02],
#                         [-4.9311e-02,  2.2667e+00, -2.0212e+00],
# ...

# %%
state_dict['_conv_stem.weight'].shape
# Out:
# torch.Size([40, 3, 3, 3])

# %%
keys_state_dict = []
for key, value in state_dict.items():
    keys_state_dict.append(key)

# %%
keys_state_dict
# Out:
# ['features.0.0.weight',
#  'features.0.1.weight',
#  'features.0.1.bias',
#  'features.0.1.running_mean',
#  'features.0.1.running_var',
#  'features.0.1.num_batches_tracked',
#  'features.1.block.0.0.weight',
#  'features.1.block.0.1.weight',
#  'features.1.block.0.1.bias',
#  'features.1.block.0.1.running_mean',
#  'features.1.block.0.1.running_var',
#  'features.1.block.0.1.num_batches_tracked',
#  'features.1.block.1.0.weight',
#  'features.1.block.1.1.weight',
#  'features.1.block.1.1.bias',
#  'features.1.block.1.1.running_mean',
#  'features.1.block.1.1.running_var',
#  'features.1.block.1.1.num_batches_tracked',
#  'features.2.block.0.0.weight',
#  'features.2.block.0.1.weight',
#  'features.2.block.0.1.bias',
#  'features.2.block.0.1.running_mean',
#  'features.2.block.0.1.running_var',
#  'features.2.block.0.1.num_batches_tracked',
#  'features.2.block.1.0.weight',
#  'features.2.block.1.1.weight',
#  'features.2.block.1.1.bias',
#  'features.2.block.1.1.running_mean',
# ...

# %%
my_keys
# Out:
# ['convbnact_stem.conv.weight',
#  'convbnact_stem.bn.weight',
#  'convbnact_stem.bn.bias',
#  'convbnact_stem.bn.running_mean',
#  'convbnact_stem.bn.running_var',
#  'convbnact_stem.bn.num_batches_tracked',
#  'bneck.0.inverted_residual.0.conv.weight',
#  'bneck.0.inverted_residual.0.bn.weight',
#  'bneck.0.inverted_residual.0.bn.bias',
#  'bneck.0.inverted_residual.0.bn.running_mean',
#  'bneck.0.inverted_residual.0.bn.running_var',
#  'bneck.0.inverted_residual.0.bn.num_batches_tracked',
#  'bneck.0.inverted_residual.1.conv.weight',
#  'bneck.0.inverted_residual.1.bn.weight',
#  'bneck.0.inverted_residual.1.bn.bias',
#  'bneck.0.inverted_residual.1.bn.running_mean',
#  'bneck.0.inverted_residual.1.bn.running_var',
#  'bneck.0.inverted_residual.1.bn.num_batches_tracked',
#  'bneck.1.inverted_residual.0.conv.weight',
#  'bneck.1.inverted_residual.0.bn.weight',
#  'bneck.1.inverted_residual.0.bn.bias',
#  'bneck.1.inverted_residual.0.bn.running_mean',
# ...

# %%
len(keys_state_dict)
# Out:
# 312

# %%
import torch
PATH = '/workdir/vpatrushev/small2/torchOK2/torchok/mobilenetv3_large_torchok.pth'
torch.save(my_tensor_state_dict, PATH)
